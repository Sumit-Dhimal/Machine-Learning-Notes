# %% [markdown]
# # Working with JSON

# %%
import pandas as pd

# %% [markdown]
# ## 1. Reading local file

# %%
pd.read_json('train.json')
# Out:
#           id      cuisine                                        ingredients
# 0      10259        greek  [romaine lettuce, black olives, grape tomatoes...
# 1      25693  southern_us  [plain flour, ground pepper, salt, tomatoes, g...
# 2      20130     filipino  [eggs, pepper, salt, mayonaise, cooking oil, g...
# 3      22213       indian                [water, vegetable oil, wheat, salt]
# 4      13162       indian  [black pepper, shallots, cornflour, cayenne pe...
# ...      ...          ...                                                ...
# 39769  29109        irish  [light brown sugar, granulated sugar, butter, ...
# 39770  11462      italian  [KRAFT Zesty Italian Dressing, purple onion, b...
# 39771   2238        irish  [eggs, citrus fruit, raisins, sourdough starte...
# 39772  41882      chinese  [boneless chicken skinless thigh, minced garli...
# 39773   2362      mexican  [green chile, jalapeno chilies, onions, ground...
#
# [39774 rows x 3 columns]

# %% [markdown]
# ## 2. Reading from api

# %%
pd.read_json('https://openlibrary.org/search.json?q=harry+potter')
# Out:
#     numFound  start  numFoundExact  num_found  \
# 0       3758      0           True       3758
# 1       3758      0           True       3758
# 2       3758      0           True       3758
# 3       3758      0           True       3758
# 4       3758      0           True       3758
# ..       ...    ...            ...        ...
# 95      3758      0           True       3758
# 96      3758      0           True       3758
# 97      3758      0           True       3758
# 98      3758      0           True       3758
# 99      3758      0           True       3758
#
#                               documentation_url             q  offset  \
# 0   https://openlibrary.org/dev/docs/api/search  harry potter     NaN
# 1   https://openlibrary.org/dev/docs/api/search  harry potter     NaN
# 2   https://openlibrary.org/dev/docs/api/search  harry potter     NaN
# 3   https://openlibrary.org/dev/docs/api/search  harry potter     NaN
# ...

# %% [markdown]
# # Working with SQL

# %%
import pandas as pd
import mysql.connector

# %%
conn = mysql.connector.connect(host='localhost', user='', password='', database='ml_project') # put your use and password

# %%
df = pd.read_sql_query("SELECT * FROM house_prices", conn)
# Out:
# C:\Users\sumit\AppData\Local\Temp\ipykernel_8832\4198952520.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql_query("SELECT * FROM house_prices", conn)

# %%
df.head()
# Out:
#    id  area_sqft  bedrooms  bathrooms  floors  age  location_score   price
# 0   1       1200         2          1       1   10               7  120000
# 1   2       1500         3          2       1    5               8  180000
# 2   3       1800         3          2       2    3               9  250000
# 3   4       2200         4          3       2    2               9  320000
# 4   5        900         2          1       1   15               6   90000
